# %%
import joblib

study = joblib.load('objects/study_lgb1.pkl')
study.trials
# Out:
# [FrozenTrial(number=0, value=None, datetime_start=datetime.datetime(2020, 2, 27, 9, 15, 46, 998958), datetime_complete=None, params={}, distributions={}, user_attrs={}, system_attrs={'_number': 0}, intermediate_values={}, trial_id=0, state=TrialState.RUNNING)]

# %%
import pandas as pd

pd.DataFrame(study.trials)
# Out:
#                                                     0
# 0   FrozenTrial(number=0, value=0.0049943803930133...
# 1   FrozenTrial(number=1, value=0.0207108088669549...
# 2   FrozenTrial(number=2, value=0.0052445416776889...
# 3   FrozenTrial(number=3, value=0.0118914321743450...
# 4   FrozenTrial(number=4, value=0.0076394112072589...
# 5   FrozenTrial(number=5, value=0.0084649485121819...
# 6   FrozenTrial(number=6, value=0.0127726743692855...
# 7   FrozenTrial(number=7, value=0.0339503388544237...
# 8   FrozenTrial(number=8, value=0.0077953774842255...
# 9   FrozenTrial(number=9, value=0.0536197328321908...
# 10  FrozenTrial(number=10, value=0.029835973381026...
# 11  FrozenTrial(number=11, value=0.003415615634620...
# 12  FrozenTrial(number=12, value=0.003464826209997...
# 13  FrozenTrial(number=13, value=0.002895398872000...
# 14  FrozenTrial(number=14, value=0.003574118514821...
# 15  FrozenTrial(number=15, value=0.002341576269692...
# ...
